# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\Hp\\Downloads\\dataset_Facebook - dataset_Facebook.csv")
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
df.mean(numeric_only=True)
# Out:
# Page total likes                                                       123194.176000
# Category                                                                    1.880000
# Post Month                                                                  7.038000
# Post Weekday                                                                4.150000
# Post Hour                                                                   7.840000
# Paid                                                                        0.278557
# Lifetime Post Total Reach                                               13903.360000
# Lifetime Post Total Impressions                                         29585.948000
# Lifetime Engaged Users                                                    920.344000
# Lifetime Post Consumers                                                   798.772000
# Lifetime Post Consumptions                                               1415.130000
# ...

# %%
df.median(numeric_only=True)
# Out:
# Page total likes                                                       129600.0
# Category                                                                    2.0
# Post Month                                                                  7.0
# Post Weekday                                                                4.0
# Post Hour                                                                   9.0
# Paid                                                                        0.0
# Lifetime Post Total Reach                                                5281.0
# Lifetime Post Total Impressions                                          9051.0
# Lifetime Engaged Users                                                    625.5
# Lifetime Post Consumers                                                   551.5
# Lifetime Post Consumptions                                                851.0
# Lifetime Post Impressions by people who have liked your Page             6255.5
# ...

# %%
df.mode(numeric_only=True)
# Out:
#     Page total likes  Category  Post Month  Post Weekday  Post Hour  Paid  \
# 0           136393.0       1.0        10.0           7.0        3.0   0.0
# 1                NaN       NaN         NaN           NaN        NaN   NaN
# 2                NaN       NaN         NaN           NaN        NaN   NaN
# 3                NaN       NaN         NaN           NaN        NaN   NaN
# 4                NaN       NaN         NaN           NaN        NaN   NaN
# 5                NaN       NaN         NaN           NaN        NaN   NaN
# 6                NaN       NaN         NaN           NaN        NaN   NaN
# 7                NaN       NaN         NaN           NaN        NaN   NaN
# 8                NaN       NaN         NaN           NaN        NaN   NaN
# 9                NaN       NaN         NaN           NaN        NaN   NaN
# 10               NaN       NaN         NaN           NaN        NaN   NaN
# 11               NaN       NaN         NaN           NaN        NaN   NaN
# ...

# %%
df.mode(numeric_only=True).iloc[0]
# Out:
# Page total likes                                                       136393.0
# Category                                                                    1.0
# Post Month                                                                 10.0
# Post Weekday                                                                7.0
# Post Hour                                                                   3.0
# Paid                                                                        0.0
# Lifetime Post Total Reach                                                 677.0
# Lifetime Post Total Impressions                                          4372.0
# Lifetime Engaged Users                                                    537.0
# Lifetime Post Consumers                                                   182.0
# Lifetime Post Consumptions                                                431.0
# Lifetime Post Impressions by people who have liked your Page             1210.0
# ...

# %%
df.std(numeric_only=True)
# Out:
# Page total likes                                                       16272.813214
# Category                                                                   0.852675
# Post Month                                                                 3.307936
# Post Weekday                                                               2.030701
# Post Hour                                                                  4.368589
# Paid                                                                       0.448739
# Lifetime Post Total Reach                                              22740.787890
# Lifetime Post Total Impressions                                        76803.246670
# Lifetime Engaged Users                                                   985.016636
# Lifetime Post Consumers                                                  882.505013
# Lifetime Post Consumptions                                              2000.594118
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
(df==0).sum()
# Out:
# Page total likes                                                         0
# Type                                                                     0
# Category                                                                 0
# Post Month                                                               0
# Post Weekday                                                             0
# Post Hour                                                                0
# Paid                                                                   360
# Lifetime Post Total Reach                                                0
# Lifetime Post Total Impressions                                          0
# Lifetime Engaged Users                                                   0
# Lifetime Post Consumers                                                  0
# Lifetime Post Consumptions                                               0
# ...

# %%
df.eq(0).sum()
# Out:
# Page total likes                                                         0
# Type                                                                     0
# Category                                                                 0
# Post Month                                                               0
# Post Weekday                                                             0
# Post Hour                                                                0
# Paid                                                                   360
# Lifetime Post Total Reach                                                0
# Lifetime Post Total Impressions                                          0
# Lifetime Engaged Users                                                   0
# Lifetime Post Consumers                                                  0
# Lifetime Post Consumptions                                               0
# ...

# %%
df.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df1=df.fillna(df.mode(numeric_only=True).iloc[0])
df1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df1.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df1.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  500.000000                  500.00000                     5.000000e+02
# mean     0.278000                13903.36000                     2.958595e+04
# ...

# %%
df2=df1[df1['like']>1000]
df2
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441  Photo         2          12             2         10
# 101            137020  Photo         2          10             4          3
# 168            135428  Photo         1           9             3         10
# 176            135195  Photo         3           9             6          3
# 199            132817  Photo         3           8             4         10
# 244            130791  Photo         2           7             3          5
# 323            123047  Photo         3           6             1         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 460             92507  Photo         3           2             1         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
df1['Type'].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
df1['Type']
# Out:
# 0       Photo
# 1      Status
# 2       Photo
# 3       Photo
# 4       Photo
#         ...
# 495     Photo
# 496     Photo
# 497     Photo
# 498     Photo
# 499     Photo
# Name: Type, Length: 500, dtype: object

# %%
df3=df1[(df1['like']>5000)&(df1['share']>10)&(df1['comment']>50)]
df3
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 244                    8072                     4010
#
#      Lifetime Post Consumptions  \
# 244                        6242
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 244                                             108752
#
#      Lifetime Post reach by people who like your Page  \
# 244                                             51456
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 244                                               3316
#
#      comment    like  share  Total Interactions
# 244      372  5172.0  790.0                6334

# %%
df4=df1[(df1['Post Weekday']==7)&(df1['Post Hour']==5)]
df4
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 125            136393  Photo         1          10             7          5
# 448             96749  Photo         1           3             7          5
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 125   0.0                        677                             1240
# 448   1.0                      14320                            21958
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 125                     236                      228
# 448                    1850                     1819
#
#      Lifetime Post Consumptions  \
# 125                         264
# 448                        2170
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 125                                               1098
# 448                                               9579
#
#      Lifetime Post reach by people who like your Page  \
# ...

# %%
df5=df1[(df1['Post Month']==5)&(df1['Post Weekday']==6)&(df1['Post Hour']>7)]
df5
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 336            119198  Photo         3           5             6         14
# 347            117764  Photo         3           5             6         13
# 348            117764  Photo         3           5             6          8
# 360            116091  Photo         1           5             6          9
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 336   0.0                       2772                             4642
# 347   0.0                       3144                             5067
# 348   1.0                       4336                             7705
# 360   0.0                       6000                            10300
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 336                     526                      479
# 347                     392                      356
# 348                     574                      484
# ...

# %%
df6=df1[df1['Lifetime People who have liked your Page and engaged with your post']>2500]
df6
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 10             139441  Status         2          12             5         10
# 38             138895  Status         2          12             7          9
# 46             138353  Status         1          12             3         11
# 142            136013  Status         2          10             3          2
# 172            135195  Status         2           9             1         10
# 223            131808  Status         2           8             6         10
# 225            131808  Status         2           7             5         14
# 244            130791   Photo         2           7             3          5
# 275            126424  Status         2           7             3         13
# 460             92507   Photo         3           2             1         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
df7=df1[(df1['Lifetime Post Impressions by people who have liked your Page']>100000)&(df1['Lifetime Post reach by people who like your Page']>5000)&(df1['Lifetime People who have liked your Page and engaged with your post']>500)]
df7
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 203            132817  Photo         3           8             2         10
# 244            130791  Photo         2           7             3          5
# 277            126424  Video         1           6             2         13
# 415            104070  Photo         1           3             4          7
# 442             98195  Photo         3           3             4         13
# 449             93684  Photo         1           2             6         13
# 460             92507  Photo         3           2             1         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 203   0.0                      72864                           205934
# 244   1.0                     180480                           319133
# 277   0.0                     139008                           277100
# 415   0.0                      49632                          1110282
# ...

# %%
s1=df1[(df1['Type']=='Photo')&(df1['Paid']==1.0)][['Category','like','Paid']]
s1
# Out:
#      Category    like  Paid
# 3           2  1572.0   1.0
# 6           3   249.0   1.0
# 7           3   325.0   1.0
# 14          2   577.0   1.0
# 17          1   678.0   1.0
# ..        ...     ...   ...
# 467         2   200.0   1.0
# 473         3   136.0   1.0
# 475         3    65.0   1.0
# 476         1   579.0   1.0
# 491         3   105.0   1.0
#
# [119 rows x 3 columns]

# %%
s2=df1[(df1['Type']=='Video')&(df1['Paid']==0.0)][['Category','like','Paid']]
s2
# Out:
#      Category   like  Paid
# 74          1   99.0   0.0
# 183         1  345.0   0.0
# 277         1  204.0   0.0

# %%
frames= [s1,s2]

answer=pd.concat(frames)
answer
# Out:
#      Category    like  Paid
# 3           2  1572.0   1.0
# 6           3   249.0   1.0
# 7           3   325.0   1.0
# 14          2   577.0   1.0
# 17          1   678.0   1.0
# ..        ...     ...   ...
# 476         1   579.0   1.0
# 491         3   105.0   1.0
# 74          1    99.0   0.0
# 183         1   345.0   0.0
# 277         1   204.0   0.0
#
# [122 rows x 3 columns]

# %%
s3=df1[(df1['Post Month']==12)&(df1['Post Weekday']==7)][['comment','like']]
s3
# Out:
#     comment   like
# 7         0  325.0
# 8         0  161.0
# 21        0    0.0
# 22        0   16.0
# 23        0   72.0
# 37       16   76.0
# 38       11  227.0
# 39        1   44.0

# %%
s4=df1[(df1['Post Month']==12)&(df1['Post Weekday']==7)][['share','Total Interactions']]
s4
# Out:
#     share  Total Interactions
# 7    14.0                 339
# 8    31.0                 192
# 21    0.0                   0
# 22    2.0                  18
# 23   24.0                  96
# 37    8.0                 100
# 38   31.0                 269
# 39   14.0                  59

# %%
ans=pd.concat([s3,s4], axis=1)
ans
# Out:
#     comment   like  share  Total Interactions
# 7         0  325.0   14.0                 339
# 8         0  161.0   31.0                 192
# 21        0    0.0    0.0                   0
# 22        0   16.0    2.0                  18
# 23        0   72.0   24.0                  96
# 37       16   76.0    8.0                 100
# 38       11  227.0   31.0                 269
# 39        1   44.0   14.0                  59

# %%
transpose=df1.transpose()
transpose
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
t=df1.T
t
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
p1=pd.pivot_table(df1,index='Type', columns='Post Weekday', values='Total Interactions')
p1
# Out:
# Post Weekday           1           2           3           4           5  \
# Type
# Link           74.000000  149.333333   81.500000  110.750000   71.750000
# Photo         245.983871  204.931034  302.288462  267.333333  204.716981
# Status        179.750000   51.000000  251.500000  324.750000  229.888889
# Video                NaN  371.500000  261.500000  174.000000  550.000000
#
# Post Weekday           6           7
# Type
# Link           89.200000   12.000000
# Photo         158.343284  156.422535
# Status        256.375000  162.666667
# Video          81.000000         NaN

# %%
pivot=df1.pivot_table(index='Type', columns='Post Weekday', values='Total Interactions')
pivot
# Out:
# Post Weekday           1           2           3           4           5  \
# Type
# Link           74.000000  149.333333   81.500000  110.750000   71.750000
# Photo         245.983871  204.931034  302.288462  267.333333  204.716981
# Status        179.750000   51.000000  251.500000  324.750000  229.888889
# Video                NaN  371.500000  261.500000  174.000000  550.000000
#
# Post Weekday           6           7
# Type
# Link           89.200000   12.000000
# Photo         158.343284  156.422535
# Status        256.375000  162.666667
# Video          81.000000         NaN
