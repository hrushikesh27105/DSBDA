# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:/Users/HRUSHIKESH/OneDrive/Desktop/DSBDA/dataset_Facebook.csv",sep=";")

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df.dtypes
# Out:
# Page total likes,Type,Category,Post Month,Post Weekday,Post Hour,Paid,Lifetime Post Total Reach,Lifetime Post Total Impressions,Lifetime Engaged Users,Lifetime Post Consumers,Lifetime Post Consumptions,Lifetime Post Impressions by people who have liked your Page,Lifetime Post reach by people who like your Page,Lifetime People who have liked your Page and engaged with your post,comment,like,share,Total Interactions    object
# dtype: object

# %%
df.shape
# Out:
# (500, 19)

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.dtypes
# Out:
# Page total likes,Type,Category,Post Month,Post Weekday,Post Hour,Paid,Lifetime Post Total Reach,Lifetime Post Total Impressions,Lifetime Engaged Users,Lifetime Post Consumers,Lifetime Post Consumptions,Lifetime Post Impressions by people who have liked your Page,Lifetime Post reach by people who like your Page,Lifetime People who have liked your Page and engaged with your post,comment,like,share,Total Interactions    object
# dtype: object

# %%
df["Paid"]=df["Paid"].fillna(df["Paid"].mean())

# %%
df["like"]=df["like"].fillna(df["like"].mean())
df["share"]=df["share"].fillna(df["share"].mean())

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
s1=df[df["Type"]=="Status"]
s1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 15             138414  Status         2          12             3         10
# 18             138414  Status         3          12             2          3
# 24             138414  Status         2          12             6         10
# 25             138458  Status         2          12             6          3
# 26             138458  Status         2          12             5         11
# 38             138895  Status         2          12             7          9
# 40             138895  Status         2          12             6         11
# ...

# %%
s2=df[(df["Type"]=="Photo")& (df["Post Month"]>10)]
s2
# Out:
#     Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441  Photo         2          12             4          3
# 2             139441  Photo         3          12             3          3
# 3             139441  Photo         2          12             2         10
# 4             139441  Photo         2          12             2          3
# 6             139441  Photo         3          12             1          3
# ..               ...    ...       ...         ...           ...        ...
# 90            137059  Photo         1          11             2          3
# 91            137059  Photo         2          11             1          9
# 92            137059  Photo         3          11             1          3
# 93            137059  Photo         3          11             7          9
# 94            137059  Photo         2          11             7          4
#
# ...

# %%
s3=df[df["Category"]==2]
s3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# ..                ...     ...       ...         ...           ...        ...
# 467             91758   Photo         2           2             5          3
# 480             86909   Photo         2           1             4         11
# 483             86491   Photo         2           1             3          3
# 496             81370   Photo         2           1             5          8
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
s4=df[(df["Lifetime Post Consumptions"]>1000)& (df["Lifetime Engaged Users"]>860)]
s4
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 488             85979   Photo         3           1             7         10
# 489             85979   Photo         3           1             7          2
# 490             85979   Photo         3           1             6         11
# 491             85979   Photo         3           1             6          3
# 493             85093   Photo         3           1             1          2
#
# ...

# %%
s5=df.iloc[:7,:6]
s5
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
# 6            139441   Photo         3          12             1          3

# %%
s6=df[(df["Page total likes"]>13500)& (df["Lifetime Engaged Users"]>860)]
s6
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 488             85979   Photo         3           1             7         10
# 489             85979   Photo         3           1             7          2
# 490             85979   Photo         3           1             6         11
# 491             85979   Photo         3           1             6          3
# 493             85093   Photo         3           1             1          2
#
# ...

# %%
s7=df[4:13]
s7
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 4             139441   Photo         2          12             2          3
# 5             139441  Status         2          12             1          9
# 6             139441   Photo         3          12             1          3
# 7             139441   Photo         3          12             7          9
# 8             139441  Status         2          12             7          3
# 9             139441   Photo         3          12             6         10
# 10            139441  Status         2          12             5         10
# 11            139441   Photo         2          12             5         10
# 12            139441   Photo         2          12             5         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 4    0.0                       7244                            13594
# ...

# %%
s8=df.iloc[:4,:4]

s8
# Out:
#    Page total likes    Type  Category  Post Month
# 0            139441   Photo         2          12
# 1            139441  Status         2          12
# 2            139441   Photo         3          12
# 3            139441   Photo         2          12

# %%
s9=df.iloc[:4,3:14]
s9
# Out:
#    Post Month  Post Weekday  Post Hour  Paid  Lifetime Post Total Reach  \
# 0          12             4          3   0.0                       2752
# 1          12             3         10   0.0                      10460
# 2          12             3          3   0.0                       2413
# 3          12             2         10   1.0                      50128
#
#    Lifetime Post Total Impressions  Lifetime Engaged Users  \
# 0                             5091                     178
# 1                            19057                    1457
# 2                             4373                     177
# 3                            87991                    2211
#
#    Lifetime Post Consumers  Lifetime Post Consumptions  \
# 0                      109                         159
# 1                     1361                        1674
# 2                      113                         154
# 3                      790                        1119
#
# ...

# %%
Trans=df.transpose()
Trans
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
merged_df1 = pd.concat([s2, s3], ignore_index=True)
merged_df1
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 1              139441  Photo         3          12             3          3
# 2              139441  Photo         2          12             2         10
# 3              139441  Photo         2          12             2          3
# 4              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 194             91758  Photo         2           2             5          3
# 195             86909  Photo         2           1             4         11
# 196             86491  Photo         2           1             3          3
# 197             81370  Photo         2           1             5          8
# 198             81370  Photo         2           1             4          4
#
# ...

# %%
df_merged = pd.merge(s8, s9, how='inner')
df_merged
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441   Photo         2          12             3         10
# 2             139441   Photo         2          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441  Status         2          12             4          3
# 5             139441  Status         2          12             3         10
# 6             139441  Status         2          12             3          3
# 7             139441  Status         2          12             2         10
# 8             139441   Photo         3          12             4          3
# 9             139441   Photo         3          12             3         10
# 10            139441   Photo         3          12             3          3
# ...

# %%
merge=s8.merge(s9)
merge
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441   Photo         2          12             3         10
# 2             139441   Photo         2          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441  Status         2          12             4          3
# 5             139441  Status         2          12             3         10
# 6             139441  Status         2          12             3          3
# 7             139441  Status         2          12             2         10
# 8             139441   Photo         3          12             4          3
# 9             139441   Photo         3          12             3         10
# 10            139441   Photo         3          12             3          3
# ...

# %%
pivot_df = df.pivot_table(
    index="Post Month",
    columns="Type",
    values="Total Interactions",
    aggfunc="mean"
)

# %%
pivot_df
# Out:
# Type              Link       Photo      Status       Video
# Post Month
# 1            66.250000  178.571429         NaN         NaN
# 2           131.000000  246.480000         NaN         NaN
# 3            46.666667  103.750000   34.000000         NaN
# 4           173.333333  212.369565  587.000000         NaN
# 5            63.000000  270.666667  162.666667         NaN
# 6                  NaN  157.521739  105.500000  271.000000
# 7                  NaN  350.159091  180.857143  409.000000
# 8                  NaN  234.866667  154.250000         NaN
# 9                  NaN  279.032258  226.000000  472.000000
# 10           95.000000  162.510204  340.750000         NaN
# 11          163.000000  183.157895  163.666667  248.333333
# 12           65.333333  227.677419  203.583333  174.000000

# %%
X = df.drop("Total Interactions", axis=1)
y = df["Total Interactions"]

# Keep only numeric
X = X.select_dtypes(include=np.number)

# Convert
X = X.values
y = y.values.reshape(-1,1)

print(X.shape, y.shape)
# Out:
# (500, 17) (500, 1)

# %%
df_sorted_likes = df.sort_values(
    by="like",
    ascending=False
)

(df_sorted_likes.head())
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
# 379   1.0                     105632                           147918
# 349   0.0                      81856                           124753
# 168   0.0                      41984                            68290
# 3     1.0                      50128                            87991
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...
